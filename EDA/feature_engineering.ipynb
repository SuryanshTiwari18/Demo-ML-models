# %% [markdown]
# ## Feature Engineering ---> It is the process of creating new and better features for our model from which we can have better insights or we can make better prediction model

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
train=pd.read_csv('tested.csv')

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
train['Family Size'] = train['SibSp'] + train['Parch'] + 1

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked  Family Size
# 0   330911   7.8292   NaN        Q            1
# 1   363272   7.0000   NaN        S            2
# 2   240276   9.6875   NaN        Q            1
# 3   315154   8.6625   NaN        S            1
# 4  3101298  12.2875   NaN        S            3

# %%
sns.barplot(x='Family Size', y='Survived', data=train)
# Out:
# <Axes: xlabel='Family Size', ylabel='Survived'>

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked  Family Size
# 0   330911   7.8292   NaN        Q            1
# 1   363272   7.0000   NaN        S            2
# 2   240276   9.6875   NaN        Q            1
# 3   315154   8.6625   NaN        S            1
# 4  3101298  12.2875   NaN        S            3

# %%
def fam_type(size):
    if size >=1 and size <=3:
        return 'Small'
    elif size >3 and size <=5:
        return 'Medium'
    else:
        return 'Large'

# %%
train['Family Type'] = train['Family Size'].apply(fam_type)

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked  Family Size Family Type
# 0   330911   7.8292   NaN        Q            1       Small
# 1   363272   7.0000   NaN        S            2       Small
# 2   240276   9.6875   NaN        Q            1       Small
# 3   315154   8.6625   NaN        S            1       Small
# ...

# %%
train['Family Type'].value_counts()
# Out:
# Family Type
# Small     384
# Medium     21
# Large      13
# Name: count, dtype: int64

# %%
sns.heatmap(pd.crosstab(train['Family Type'], train['Survived'],normalize=True)*100)
# Out:
# <Axes: xlabel='Survived', ylabel='Family Type'>

# %%
train['Individual Fare']=train['Fare']/train['Family Size']

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked  Family Size Family Type  Individual Fare
# 0   330911   7.8292   NaN        Q            1       Small         7.829200
# 1   363272   7.0000   NaN        S            2       Small         3.500000
# ...

# %%
train['Name Prefix']=train['Name'].str.split(',').str[1].str.split('.').str[0].str.strip()

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked  Family Size Family Type  Individual Fare  \
# 0   330911   7.8292   NaN        Q            1       Small         7.829200
# 1   363272   7.0000   NaN        S            2       Small         3.500000
# ...

# %%
train['Name Prefix'].value_counts()
# Out:
# Name Prefix
# Mr        240
# Miss       78
# Mrs        72
# Master     21
# Col         2
# Rev         2
# Ms          1
# Dr          1
# Dona        1
# Name: count, dtype: int64
