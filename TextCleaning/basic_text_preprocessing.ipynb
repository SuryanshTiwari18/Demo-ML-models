# %%
import pandas as pd

# %%
d=pd.read_csv("test_data_cleaning.csv")

# %%
## split()

# %%
# word tokenize

# %%
sent_1="I am going to delhi"

# %%
sent_1.split()
# Out:
# ['I', 'am', 'going', 'to', 'delhi']

# %%
para="I am going to delhi. I will stay there for 3 days. If you are free at that time please do let me know"

# %%
para.split('.')
# Out:
# ['I am going to delhi',
#  ' I will stay there for 3 days',
#  ' If you are free at that time please do let me know']

# %%
sent_2="I am going to delhi!"

# %%
sent_2.split()
# Out:
# ['I', 'am', 'going', 'to', 'delhi!']

# %%
sent = "Hey i am in New Delhi!"

# %%
sent.split()
# Out:
# ['Hey', 'i', 'am', 'in', 'New', 'Delhi!']

# %%
## Reguilar Expression

# %%
## . ! ?

# %%
import re

# %%
re.findall("[\w']+",sent)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\w'
# <>:1: SyntaxWarning: invalid escape sequence '\w'
# C:\Users\Asus\AppData\Local\Temp\ipykernel_21600\3941724944.py:1: SyntaxWarning: invalid escape sequence '\w'
#   re.findall("[\w']+",sent)
# ['Hey', 'i', 'am', 'in', 'New', 'Delhi']

# %%
text="Hey how are you ?  I am fine ! I was searching for you ."

# %%
re.compile('[.!?]').split(text)
# Out:
# ['Hey how are you ', '  I am fine ', ' I was searching for you ', '']

# %%
"I have a Ph.D in A.I!".split()
# Out:
# ['I', 'have', 'a', 'Ph.D', 'in', 'A.I!']

# %%
## NLTK ---> Natural Language Tool Kit

# %%
## Word_splitting, sentence_splitting

# %%
from nltk.tokenize import word_tokenize, sent_tokenize

# %%
# import nltk
# nltk.download('punkt')

# %%
# nltk.download('punkt_tab')

# %%
sent_1="I have a Ph.D in A.i"

# %%
word_tokenize(sent_1)
# Out:
# ['I', 'have', 'a', 'Ph.D', 'in', 'A.i']

# %%
sent_2 = "we're here to help . mail us at example@email.com"

# %%
word_tokenize(sent_2)
# Out:
# ['we',
#  "'re",
#  'here',
#  'to',
#  'help',
#  '.',
#  'mail',
#  'us',
#  'at',
#  'example',
#  '@',
#  'email.com']

# %%
sent_3='A 5km ride costs us around $20.'

# %%
word_tokenize(sent_3)
# Out:
# ['A', '5km', 'ride', 'costs', 'us', 'around', '$', '20', '.']

# %%
text="Hey how are you ?  I am fine ! I was searching for you ."

# %%
sent_tokenize(text)
# Out:
# ['Hey how are you ?', 'I am fine !', 'I was searching for you .']

# %%
# Spacy

# %%
import spacy

# %%
nlp=spacy.load('en_core_web_sm')

# %%
text_1 = 'I have a Ph.D degree in A.I'

# %%
text_2="we're here to help . mail us at example@email.com"

# %%
text_3="A 5km ride costs us around $20."

# %%
tok1=nlp(text_3)

# %%
for i in tok1:
    print(i)
# Out:
# A
# 5
# km
# ride
# costs
# us
# around
# $
# 20
# .

# %%
from nltk.stem import PorterStemmer

# %%
ps=PorterStemmer()

# %%
words=["stories","easily","running","ran","runs","fairly"]

# %%
for i in words:
    print(i,"-->",ps.stem(i))
# Out:
# stories --> stori
# easily --> easili
# running --> run
# ran --> ran
# runs --> run
# fairly --> fairli

# %%
## these words will work for machine, machine will be able to understand
## but what if we need to show the root word to humans, they need the correct word
## for this we will dive into lemmatization

# %%
import nltk

# %%
from nltk.stem import WordNetLemmatizer

# %%
from nltk.corpus import wordnet

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Asus\AppData\Roaming\nltk_data...
# True

# %%
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\Asus\AppData\Roaming\nltk_data...
# True

# %%
lemmatizer=WordNetLemmatizer()

# %%
## running, better, mice

# %%
lemmatizer.lemmatize("running",pos=wordnet.VERB)
# Out:
# 'run'

# %%
lemmatizer.lemmatize("better",pos=wordnet.ADJ)
# Out:
# 'good'

# %%
lemmatizer.lemmatize("mice",pos=wordnet.NOUN)
# Out:
# 'mouse'

# %%
lemmatizer.lemmatize("fairly",pos=wordnet.ADV)
# Out:
# 'fairly'

# %%
lemmatizer.lemmatize("easily",pos=wordnet.ADV)
# Out:
# 'easily'
